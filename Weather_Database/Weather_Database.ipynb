# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        # YOUR CODE HERE
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 756

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6c4be0baa61f7a981e04b794df263977'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(20)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()

        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_d = city_weather["weather"]
        city_weather_description = city_weather_d[0]["description"]
        
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | cayenne
# Processing Record 4 of Set 1 | lamu
# Processing Record 5 of Set 1 | lebu
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | hit
# Processing Record 10 of Set 1 | camacha
# Processing Record 11 of Set 1 | linjiang
# Processing Record 12 of Set 1 | saint-pierre
# Processing Record 13 of Set 1 | katangli
# Processing Record 14 of Set 1 | antofagasta
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | salalah
# Processing Record 17 of Set 1 | waitati
# Processing Record 18 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 1 | cabo san lucas
# Processing Record 20 of Set 1 | krasnyy yar
# Processing Record 21 of Set 1 | severo-kurilsk
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | ucluelet
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | kargopol
# Processing Record 26 of Set 1 | cherskiy
# Processing Record 27 of Set 1 | ozgon
# City not found. Skipping...
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | kogon
# Processing Record 31 of Set 1 | uaua
# Processing Record 32 of Set 1 | qujing
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | dikson
# Processing Record 35 of Set 1 | camenca
# Processing Record 36 of Set 1 | jos
# Processing Record 37 of Set 1 | tiksi
# Processing Record 38 of Set 1 | bichena
# Processing Record 39 of Set 1 | nemuro
# Processing Record 40 of Set 1 | hithadhoo
# Processing Record 41 of Set 1 | saurimo
# Processing Record 42 of Set 1 | hilo
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | nsanje
# Processing Record 45 of Set 1 | adrar
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | victoria
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 1 | amposta
# Processing Record 1 of Set 2 | karasburg
# Processing Record 2 of Set 2 | teneguiban
# City not found. Skipping...
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | sterling
# Processing Record 5 of Set 2 | tasiilaq
# Processing Record 6 of Set 2 | hambantota
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | byron bay
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | valdivia
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | sao joao da barra
# Processing Record 13 of Set 2 | grants pass
# Processing Record 14 of Set 2 | cabedelo
# Processing Record 15 of Set 2 | bredasdorp
# Processing Record 16 of Set 2 | qaanaaq
# Processing Record 17 of Set 2 | dezful
# Processing Record 18 of Set 2 | taulov
# Processing Record 19 of Set 2 | kihei
# Processing Record 20 of Set 2 | mecca
# Processing Record 21 of Set 2 | taoudenni
# Processing Record 22 of Set 2 | izazi
# Processing Record 23 of Set 2 | havoysund
# Processing Record 24 of Set 2 | lompoc
# Processing Record 25 of Set 2 | katima mulilo
# Processing Record 26 of Set 2 | katsuura
# Processing Record 27 of Set 2 | carnarvon
# Processing Record 28 of Set 2 | saint-augustin
# Processing Record 29 of Set 2 | kondoa
# Processing Record 30 of Set 2 | souillac
# Processing Record 31 of Set 2 | mar del plata
# Processing Record 32 of Set 2 | kropotkin
# Processing Record 33 of Set 2 | hobart
# Processing Record 34 of Set 2 | scarborough
# Processing Record 35 of Set 2 | praia
# Processing Record 36 of Set 2 | cape canaveral
# Processing Record 37 of Set 2 | kiunga
# Processing Record 38 of Set 2 | bethel
# Processing Record 39 of Set 2 | san patricio
# Processing Record 40 of Set 2 | palmer
# Processing Record 41 of Set 2 | maragogi
# Processing Record 42 of Set 2 | alice springs
# Processing Record 43 of Set 2 | alofi
# Processing Record 44 of Set 2 | albany
# Processing Record 45 of Set 2 | vila
# Processing Record 46 of Set 2 | talaya
# Processing Record 47 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 2 | faanui
# Processing Record 49 of Set 2 | kungurtug
# Processing Record 50 of Set 2 | port alfred
# Processing Record 1 of Set 3 | jitra
# Processing Record 2 of Set 3 | tarauaca
# Processing Record 3 of Set 3 | puerto ayora
# Processing Record 4 of Set 3 | machiques
# Processing Record 5 of Set 3 | alekseyevskaya
# Processing Record 6 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 3 | mao
# Processing Record 8 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 3 | saint-philippe
# Processing Record 10 of Set 3 | kruisfontein
# Processing Record 11 of Set 3 | bonoua
# Processing Record 12 of Set 3 | butaritari
# Processing Record 13 of Set 3 | irituia
# Processing Record 14 of Set 3 | tuktoyaktuk
# Processing Record 15 of Set 3 | banjarmasin
# Processing Record 16 of Set 3 | cessnock
# Processing Record 17 of Set 3 | susanville
# Processing Record 18 of Set 3 | bilibino
# Processing Record 19 of Set 3 | boa vista
# Processing Record 20 of Set 3 | clarence town
# Processing Record 21 of Set 3 | okhotsk
# Processing Record 22 of Set 3 | roald
# Processing Record 23 of Set 3 | flinders
# Processing Record 24 of Set 3 | bluff
# Processing Record 25 of Set 3 | vao
# Processing Record 26 of Set 3 | chokurdakh
# Processing Record 27 of Set 3 | panixtlahuaca
# City not found. Skipping...
# Processing Record 28 of Set 3 | east london
# Processing Record 29 of Set 3 | westport
# Processing Record 30 of Set 3 | falavarjan
# Processing Record 31 of Set 3 | fatezh
# Processing Record 32 of Set 3 | libertador general san martin
# Processing Record 33 of Set 3 | nisia floresta
# Processing Record 34 of Set 3 | baykit
# Processing Record 35 of Set 3 | livingstonia
# Processing Record 36 of Set 3 | nouadhibou
# Processing Record 37 of Set 3 | veraval
# Processing Record 38 of Set 3 | aitape
# Processing Record 39 of Set 3 | los llanos de aridane
# Processing Record 40 of Set 3 | narsaq
# Processing Record 41 of Set 3 | beringovskiy
# Processing Record 42 of Set 3 | upernavik
# Processing Record 43 of Set 3 | birin
# Processing Record 44 of Set 3 | minden
# Processing Record 45 of Set 3 | port elizabeth
# Processing Record 46 of Set 3 | beira
# Processing Record 47 of Set 3 | mayo
# Processing Record 48 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 3 | cervo
# Processing Record 50 of Set 3 | dongsheng
# Processing Record 1 of Set 4 | sioux lookout
# Processing Record 2 of Set 4 | aykhal
# Processing Record 3 of Set 4 | quesnel
# Processing Record 4 of Set 4 | aybak
# City not found. Skipping...
# Processing Record 5 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 6 of Set 4 | medvedevo
# Processing Record 7 of Set 4 | laguna
# Processing Record 8 of Set 4 | begamganj
# Processing Record 9 of Set 4 | vestmannaeyjar
# Processing Record 10 of Set 4 | torbay
# Processing Record 11 of Set 4 | porangatu
# Processing Record 12 of Set 4 | stornoway
# Processing Record 13 of Set 4 | kirakira
# Processing Record 14 of Set 4 | yar-sale
# Processing Record 15 of Set 4 | sitka
# Processing Record 16 of Set 4 | bathsheba
# Processing Record 17 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 18 of Set 4 | leh
# Processing Record 19 of Set 4 | berlevag
# Processing Record 20 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 4 | hasaki
# Processing Record 22 of Set 4 | brae
# Processing Record 23 of Set 4 | tabuk
# Processing Record 24 of Set 4 | srednekolymsk
# Processing Record 25 of Set 4 | pacific grove
# Processing Record 26 of Set 4 | meulaboh
# Processing Record 27 of Set 4 | chuy
# Processing Record 28 of Set 4 | guozhen
# Processing Record 29 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 4 | san julian
# Processing Record 31 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 32 of Set 4 | lebedyn
# Processing Record 33 of Set 4 | waipawa
# Processing Record 34 of Set 4 | jacareacanga
# Processing Record 35 of Set 4 | chumikan
# Processing Record 36 of Set 4 | dawei
# Processing Record 37 of Set 4 | kodiak
# Processing Record 38 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 39 of Set 4 | pevek
# Processing Record 40 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 4 | umm kaddadah
# Processing Record 42 of Set 4 | mahebourg
# Processing Record 43 of Set 4 | provideniya
# Processing Record 44 of Set 4 | challans
# Processing Record 45 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 4 | phayao
# Processing Record 47 of Set 4 | tuatapere
# Processing Record 48 of Set 4 | ribeira grande
# Processing Record 49 of Set 4 | castro
# Processing Record 50 of Set 4 | dauphin
# Processing Record 1 of Set 5 | bengkulu
# Processing Record 2 of Set 5 | poum
# Processing Record 3 of Set 5 | ilulissat
# Processing Record 4 of Set 5 | henties bay
# Processing Record 5 of Set 5 | horsham
# Processing Record 6 of Set 5 | bambous virieux
# Processing Record 7 of Set 5 | qingyuan
# Processing Record 8 of Set 5 | husavik
# Processing Record 9 of Set 5 | chapais
# Processing Record 10 of Set 5 | omboue
# Processing Record 11 of Set 5 | cockburn town
# Processing Record 12 of Set 5 | lagoa
# Processing Record 13 of Set 5 | daxian
# City not found. Skipping...
# Processing Record 14 of Set 5 | atasu
# Processing Record 15 of Set 5 | markovo
# Processing Record 16 of Set 5 | kaitangata
# Processing Record 17 of Set 5 | tankara
# Processing Record 18 of Set 5 | zhigansk
# Processing Record 19 of Set 5 | klaksvik
# Processing Record 20 of Set 5 | nabire
# Processing Record 21 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 5 | port-gentil
# Processing Record 24 of Set 5 | norman wells
# Processing Record 25 of Set 5 | magadi
# Processing Record 26 of Set 5 | grand gaube
# Processing Record 27 of Set 5 | sao filipe
# Processing Record 28 of Set 5 | shizunai
# Processing Record 29 of Set 5 | kaeo
# Processing Record 30 of Set 5 | pierre
# Processing Record 31 of Set 5 | sobolevo
# Processing Record 32 of Set 5 | geraldton
# Processing Record 33 of Set 5 | uruguaiana
# Processing Record 34 of Set 5 | nikolskoye
# Processing Record 35 of Set 5 | lapeer
# Processing Record 36 of Set 5 | beyneu
# Processing Record 37 of Set 5 | loreto
# Processing Record 38 of Set 5 | conceicao do araguaia
# Processing Record 39 of Set 5 | vila franca do campo
# Processing Record 40 of Set 5 | zhangjiakou
# Processing Record 41 of Set 5 | russell
# Processing Record 42 of Set 5 | arima
# Processing Record 43 of Set 5 | vadinsk
# Processing Record 44 of Set 5 | calderitas
# Processing Record 45 of Set 5 | kahului
# Processing Record 46 of Set 5 | ancud
# Processing Record 47 of Set 5 | misratah
# Processing Record 48 of Set 5 | mezen
# Processing Record 49 of Set 5 | purpe
# Processing Record 50 of Set 5 | saint-remi
# Processing Record 1 of Set 6 | xining
# Processing Record 2 of Set 6 | tingo maria
# Processing Record 3 of Set 6 | longyearbyen
# Processing Record 4 of Set 6 | valreas
# Processing Record 5 of Set 6 | te anau
# Processing Record 6 of Set 6 | nhulunbuy
# Processing Record 7 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 8 of Set 6 | waingapu
# Processing Record 9 of Set 6 | tigil
# Processing Record 10 of Set 6 | iqaluit
# Processing Record 11 of Set 6 | pimenteiras
# Processing Record 12 of Set 6 | callaway
# Processing Record 13 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 6 | kedrovyy
# Processing Record 15 of Set 6 | saint-georges
# Processing Record 16 of Set 6 | liptovsky hradok
# Processing Record 17 of Set 6 | kloulklubed
# Processing Record 18 of Set 6 | manzhouli
# Processing Record 19 of Set 6 | iracoubo
# Processing Record 20 of Set 6 | zhaodong
# Processing Record 21 of Set 6 | kawana waters
# City not found. Skipping...
# Processing Record 22 of Set 6 | touros
# Processing Record 23 of Set 6 | turukhansk
# Processing Record 24 of Set 6 | alexandria
# Processing Record 25 of Set 6 | fortuna
# Processing Record 26 of Set 6 | prieska
# Processing Record 27 of Set 6 | sur
# Processing Record 28 of Set 6 | mudkhed
# Processing Record 29 of Set 6 | san antonio
# Processing Record 30 of Set 6 | vardo
# Processing Record 31 of Set 6 | losal
# Processing Record 32 of Set 6 | san blas
# Processing Record 33 of Set 6 | san quintin
# Processing Record 34 of Set 6 | santana do livramento
# Processing Record 35 of Set 6 | kalmunai
# Processing Record 36 of Set 6 | gigmoto
# Processing Record 37 of Set 6 | antigonish
# Processing Record 38 of Set 6 | coquimbo
# Processing Record 39 of Set 6 | tahta
# Processing Record 40 of Set 6 | mehamn
# Processing Record 41 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 6 | santa isabel
# Processing Record 43 of Set 6 | tripoli
# Processing Record 44 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 6 | puerto cortes
# City not found. Skipping...
# Processing Record 46 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 6 | san cristobal
# Processing Record 48 of Set 6 | khatanga
# Processing Record 49 of Set 6 | mgandu
# Processing Record 50 of Set 6 | kavieng
# Processing Record 1 of Set 7 | nenjiang
# Processing Record 2 of Set 7 | scottsbluff
# Processing Record 3 of Set 7 | airai
# Processing Record 4 of Set 7 | leningradskiy
# Processing Record 5 of Set 7 | coahuayana
# Processing Record 6 of Set 7 | jalu
# Processing Record 7 of Set 7 | soyo
# Processing Record 8 of Set 7 | vera cruz
# Processing Record 9 of Set 7 | talakan
# Processing Record 10 of Set 7 | goderich
# Processing Record 11 of Set 7 | ostrovnoy
# Processing Record 12 of Set 7 | namibe
# Processing Record 13 of Set 7 | kimbe
# Processing Record 14 of Set 7 | olga
# Processing Record 15 of Set 7 | charters towers
# Processing Record 16 of Set 7 | aswan
# Processing Record 17 of Set 7 | guerrero negro
# Processing Record 18 of Set 7 | bafq
# Processing Record 19 of Set 7 | koronadal proper
# City not found. Skipping...
# Processing Record 20 of Set 7 | richards bay
# Processing Record 21 of Set 7 | camacari
# Processing Record 22 of Set 7 | barrow
# Processing Record 23 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 7 | pombia
# Processing Record 25 of Set 7 | esperance
# Processing Record 26 of Set 7 | imeni poliny osipenko
# Processing Record 27 of Set 7 | ponta do sol
# Processing Record 28 of Set 7 | nakajo
# City not found. Skipping...
# Processing Record 29 of Set 7 | ulaangom
# Processing Record 30 of Set 7 | yumen
# Processing Record 31 of Set 7 | gorontalo
# Processing Record 32 of Set 7 | sao jose da coroa grande
# Processing Record 33 of Set 7 | sinegorye
# Processing Record 34 of Set 7 | barpathar
# Processing Record 35 of Set 7 | sayat
# Processing Record 36 of Set 7 | tadine
# Processing Record 37 of Set 7 | hastings
# Processing Record 38 of Set 7 | champerico
# Processing Record 39 of Set 7 | phangnga
# Processing Record 40 of Set 7 | port hardy
# Processing Record 41 of Set 7 | zalantun
# Processing Record 42 of Set 7 | dunedin
# Processing Record 43 of Set 7 | yerbogachen
# Processing Record 44 of Set 7 | mount gambier
# Processing Record 45 of Set 7 | belle fourche
# Processing Record 46 of Set 7 | hofn
# Processing Record 47 of Set 7 | phonhong
# Processing Record 48 of Set 7 | sarangani
# Processing Record 49 of Set 7 | himora
# City not found. Skipping...
# Processing Record 50 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 1 of Set 8 | dingle
# Processing Record 2 of Set 8 | cooma
# Processing Record 3 of Set 8 | aracatuba
# Processing Record 4 of Set 8 | flin flon
# Processing Record 5 of Set 8 | mandera
# Processing Record 6 of Set 8 | abnub
# Processing Record 7 of Set 8 | pelym
# Processing Record 8 of Set 8 | batsfjord
# Processing Record 9 of Set 8 | calvinia
# Processing Record 10 of Set 8 | basco
# Processing Record 11 of Set 8 | purranque
# Processing Record 12 of Set 8 | paraiso
# Processing Record 13 of Set 8 | rovaniemi
# Processing Record 14 of Set 8 | igurubi
# Processing Record 15 of Set 8 | cidreira
# Processing Record 16 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 17 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 18 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 19 of Set 8 | marawi
# Processing Record 20 of Set 8 | port macquarie
# Processing Record 21 of Set 8 | maridi
# Processing Record 22 of Set 8 | batemans bay
# Processing Record 23 of Set 8 | namatanai
# Processing Record 24 of Set 8 | hualmay
# Processing Record 25 of Set 8 | trairi
# Processing Record 26 of Set 8 | bloomington
# Processing Record 27 of Set 8 | kirovskiy
# Processing Record 28 of Set 8 | wanlaweyn
# Processing Record 29 of Set 8 | amapa
# Processing Record 30 of Set 8 | kyra
# Processing Record 31 of Set 8 | tchibanga
# Processing Record 32 of Set 8 | surt
# Processing Record 33 of Set 8 | mujiayingzi
# Processing Record 34 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 8 | camanducaia
# Processing Record 36 of Set 8 | pushkinskiye gory
# Processing Record 37 of Set 8 | linhares
# Processing Record 38 of Set 8 | shenjiamen
# Processing Record 39 of Set 8 | zaria
# Processing Record 40 of Set 8 | havelock
# Processing Record 41 of Set 8 | thompson
# Processing Record 42 of Set 8 | santiago del estero
# Processing Record 43 of Set 8 | saint-francois
# Processing Record 44 of Set 8 | bar harbor
# Processing Record 45 of Set 8 | tual
# Processing Record 46 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 8 | lasa
# Processing Record 49 of Set 8 | port hedland
# Processing Record 50 of Set 8 | smiltene
# Processing Record 1 of Set 9 | half moon bay
# Processing Record 2 of Set 9 | la malbaie
# Processing Record 3 of Set 9 | frontera
# Processing Record 4 of Set 9 | clyde river
# Processing Record 5 of Set 9 | mogadishu
# Processing Record 6 of Set 9 | tessalit
# Processing Record 7 of Set 9 | nishihara
# Processing Record 8 of Set 9 | dortyol
# Processing Record 9 of Set 9 | zinder
# Processing Record 10 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 9 | north platte
# Processing Record 12 of Set 9 | broken hill
# Processing Record 13 of Set 9 | nelson bay
# Processing Record 14 of Set 9 | qasigiannguit
# Processing Record 15 of Set 9 | maymanak
# City not found. Skipping...
# Processing Record 16 of Set 9 | balimo
# City not found. Skipping...
# Processing Record 17 of Set 9 | axim
# Processing Record 18 of Set 9 | mount isa
# Processing Record 19 of Set 9 | prilep
# Processing Record 20 of Set 9 | pathein
# Processing Record 21 of Set 9 | oksfjord
# Processing Record 22 of Set 9 | kalmar
# Processing Record 23 of Set 9 | storforshei
# Processing Record 24 of Set 9 | lata
# Processing Record 25 of Set 9 | inzhavino
# Processing Record 26 of Set 9 | nyurba
# Processing Record 27 of Set 9 | kanzaki
# Processing Record 28 of Set 9 | yulara
# Processing Record 29 of Set 9 | sistranda
# Processing Record 30 of Set 9 | honningsvag
# Processing Record 31 of Set 9 | auki
# Processing Record 32 of Set 9 | quatre cocos
# Processing Record 33 of Set 9 | bow island
# Processing Record 34 of Set 9 | senanga
# Processing Record 35 of Set 9 | ca mau
# Processing Record 36 of Set 9 | rae bareli
# Processing Record 37 of Set 9 | andros town
# Processing Record 38 of Set 9 | edea
# Processing Record 39 of Set 9 | luderitz
# Processing Record 40 of Set 9 | coihaique
# Processing Record 41 of Set 9 | salinopolis
# Processing Record 42 of Set 9 | xuddur
# Processing Record 43 of Set 9 | samandag
# Processing Record 44 of Set 9 | sadao
# Processing Record 45 of Set 9 | thohoyandou
# Processing Record 46 of Set 9 | maple creek
# Processing Record 47 of Set 9 | manacapuru
# Processing Record 48 of Set 9 | riberalta
# Processing Record 49 of Set 9 | port shepstone
# Processing Record 50 of Set 9 | umm lajj
# Processing Record 1 of Set 10 | georgetown
# Processing Record 2 of Set 10 | tarakan
# Processing Record 3 of Set 10 | naze
# Processing Record 4 of Set 10 | phan thiet
# Processing Record 5 of Set 10 | saint anthony
# Processing Record 6 of Set 10 | auchi
# Processing Record 7 of Set 10 | maraba
# Processing Record 8 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 9 of Set 10 | la rioja
# Processing Record 10 of Set 10 | bekhtery
# Processing Record 11 of Set 10 | baruun-urt
# Processing Record 12 of Set 10 | pousat
# City not found. Skipping...
# Processing Record 13 of Set 10 | praia da vitoria
# Processing Record 14 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 10 | padang
# Processing Record 16 of Set 10 | iesolo
# Processing Record 17 of Set 10 | vostok
# Processing Record 18 of Set 10 | bubaque
# Processing Record 19 of Set 10 | tukrah
# Processing Record 20 of Set 10 | dwarka
# Processing Record 21 of Set 10 | hay river
# Processing Record 22 of Set 10 | auka
# Processing Record 23 of Set 10 | saveh
# Processing Record 24 of Set 10 | treinta y tres
# Processing Record 25 of Set 10 | lubao
# Processing Record 26 of Set 10 | tulum
# Processing Record 27 of Set 10 | anloga
# Processing Record 28 of Set 10 | ust-donetskiy
# Processing Record 29 of Set 10 | viedma
# Processing Record 30 of Set 10 | sechura
# Processing Record 31 of Set 10 | manjacaze
# Processing Record 32 of Set 10 | lander
# Processing Record 33 of Set 10 | sharan
# Processing Record 34 of Set 10 | hamilton
# Processing Record 35 of Set 10 | pucallpa
# Processing Record 36 of Set 10 | havre-saint-pierre
# Processing Record 37 of Set 10 | sisimiut
# Processing Record 38 of Set 10 | ossora
# Processing Record 39 of Set 10 | kununurra
# Processing Record 40 of Set 10 | antalaha
# Processing Record 41 of Set 10 | phalaborwa
# Processing Record 42 of Set 10 | ratnagiri
# Processing Record 43 of Set 10 | todos santos
# Processing Record 44 of Set 10 | udachnyy
# Processing Record 45 of Set 10 | constitucion
# Processing Record 46 of Set 10 | port keats
# Processing Record 47 of Set 10 | maldonado
# Processing Record 48 of Set 10 | arawa
# Processing Record 49 of Set 10 | rio grande
# Processing Record 50 of Set 10 | sovetskiy
# Processing Record 1 of Set 11 | sapele
# Processing Record 2 of Set 11 | college
# Processing Record 3 of Set 11 | bambanglipuro
# Processing Record 4 of Set 11 | itoman
# Processing Record 5 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 6 of Set 11 | denpasar
# Processing Record 7 of Set 11 | dedza
# Processing Record 8 of Set 11 | porbandar
# Processing Record 9 of Set 11 | magomeni
# Processing Record 10 of Set 11 | mbinga
# Processing Record 11 of Set 11 | beloha
# Processing Record 12 of Set 11 | isangel
# Processing Record 13 of Set 11 | margate
# Processing Record 14 of Set 11 | gilbues
# Processing Record 15 of Set 11 | channel-port aux basques
# Processing Record 16 of Set 11 | bolshaya irba
# City not found. Skipping...
# Processing Record 17 of Set 11 | calama
# Processing Record 18 of Set 11 | talnakh
# Processing Record 19 of Set 11 | baykalsk
# Processing Record 20 of Set 11 | rondonopolis
# Processing Record 21 of Set 11 | samarai
# Processing Record 22 of Set 11 | moree
# Processing Record 23 of Set 11 | caravelas
# Processing Record 24 of Set 11 | lulea
# Processing Record 25 of Set 11 | minab
# Processing Record 26 of Set 11 | gazojak
# Processing Record 27 of Set 11 | codrington
# Processing Record 28 of Set 11 | qandala
# Processing Record 29 of Set 11 | pinhao
# Processing Record 30 of Set 11 | buala
# Processing Record 31 of Set 11 | soe
# Processing Record 32 of Set 11 | altay
# Processing Record 33 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 11 | tuntum
# Processing Record 35 of Set 11 | pandan
# Processing Record 36 of Set 11 | batagay-alyta
# Processing Record 37 of Set 11 | khabary
# Processing Record 38 of Set 11 | fez
# Processing Record 39 of Set 11 | broome
# Processing Record 40 of Set 11 | christchurch
# Processing Record 41 of Set 11 | saint george
# Processing Record 42 of Set 11 | krasnoarmeysk
# Processing Record 43 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 44 of Set 11 | mangai
# Processing Record 45 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 46 of Set 11 | ola
# Processing Record 47 of Set 11 | oyo
# Processing Record 48 of Set 11 | hunfeld
# Processing Record 49 of Set 11 | george
# Processing Record 50 of Set 11 | denau
# City not found. Skipping...
# Processing Record 1 of Set 12 | nome
# Processing Record 2 of Set 12 | grindavik
# Processing Record 3 of Set 12 | eucaliptus
# Processing Record 4 of Set 12 | papara
# Processing Record 5 of Set 12 | dapaong
# Processing Record 6 of Set 12 | iwanai
# Processing Record 7 of Set 12 | bahir dar
# Processing Record 8 of Set 12 | kargasok
# Processing Record 9 of Set 12 | hearst
# Processing Record 10 of Set 12 | canutama
# Processing Record 11 of Set 12 | mineiros
# Processing Record 12 of Set 12 | limbang
# Processing Record 13 of Set 12 | dovolnoye
# Processing Record 14 of Set 12 | svetlogorsk
# Processing Record 15 of Set 12 | kieta
# Processing Record 16 of Set 12 | ketchikan
# Processing Record 17 of Set 12 | kupang
# Processing Record 18 of Set 12 | thunder bay
# Processing Record 19 of Set 12 | nova paka
# Processing Record 20 of Set 12 | bintulu
# Processing Record 21 of Set 12 | empangeni
# Processing Record 22 of Set 12 | hohhot
# Processing Record 23 of Set 12 | narasannapeta
# Processing Record 24 of Set 12 | curup
# Processing Record 25 of Set 12 | sao carlos
# Processing Record 26 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 27 of Set 12 | nyzhni sirohozy
# Processing Record 28 of Set 12 | oranjestad
# Processing Record 29 of Set 12 | san rafael
# Processing Record 30 of Set 12 | groa
# Processing Record 31 of Set 12 | pangai
# Processing Record 32 of Set 12 | atambua
# Processing Record 33 of Set 12 | ulety
# Processing Record 34 of Set 12 | tuy hoa
# Processing Record 35 of Set 12 | sinnamary
# Processing Record 36 of Set 12 | zeya
# Processing Record 37 of Set 12 | srandakan
# Processing Record 38 of Set 12 | sayyan
# Processing Record 39 of Set 12 | makaha
# Processing Record 40 of Set 12 | indianola
# Processing Record 41 of Set 12 | akureyri
# Processing Record 42 of Set 12 | sokolo
# Processing Record 43 of Set 12 | pringsewu
# Processing Record 44 of Set 12 | campos belos
# Processing Record 45 of Set 12 | bellavista
# Processing Record 46 of Set 12 | upplands-vasby
# City not found. Skipping...
# Processing Record 47 of Set 12 | capoterra
# Processing Record 48 of Set 12 | cairns
# Processing Record 49 of Set 12 | teknaf
# Processing Record 50 of Set 12 | upata
# Processing Record 1 of Set 13 | crotone
# Processing Record 2 of Set 13 | mezhdurechensk
# Processing Record 3 of Set 13 | tlahualilo
# City not found. Skipping...
# Processing Record 4 of Set 13 | ust-maya
# Processing Record 5 of Set 13 | brewster
# Processing Record 6 of Set 13 | kaithal
# Processing Record 7 of Set 13 | qaqortoq
# Processing Record 8 of Set 13 | jumla
# Processing Record 9 of Set 13 | baherden
# Processing Record 10 of Set 13 | casa nova
# Processing Record 11 of Set 13 | zlatoustovsk
# City not found. Skipping...
# Processing Record 12 of Set 13 | labuhan
# Processing Record 13 of Set 13 | carlos antonio lopez
# Processing Record 14 of Set 13 | saldanha
# Processing Record 15 of Set 13 | sambava
# Processing Record 16 of Set 13 | zaysan
# Processing Record 17 of Set 13 | pangody
# Processing Record 18 of Set 13 | lucapa
# Processing Record 19 of Set 13 | itarema
# Processing Record 20 of Set 13 | innisfail
# Processing Record 21 of Set 13 | mandi bahauddin
# Processing Record 22 of Set 13 | shenxian
# Processing Record 23 of Set 13 | high level
# Processing Record 24 of Set 13 | suntar
# Processing Record 25 of Set 13 | hurricane
# Processing Record 26 of Set 13 | klyuchi
# Processing Record 27 of Set 13 | cap-aux-meules
# Processing Record 28 of Set 13 | shimoda
# Processing Record 29 of Set 13 | golovchino
# Processing Record 30 of Set 13 | mayya
# Processing Record 31 of Set 13 | winnemucca
# Processing Record 32 of Set 13 | sampit
# Processing Record 33 of Set 13 | cartagena
# Processing Record 34 of Set 13 | tautira
# Processing Record 35 of Set 13 | eyl
# Processing Record 36 of Set 13 | hede
# Processing Record 37 of Set 13 | samarinda
# Processing Record 38 of Set 13 | sungaipenuh
# Processing Record 39 of Set 13 | mukilteo
# Processing Record 40 of Set 13 | praya
# Processing Record 41 of Set 13 | mahibadhoo
# Processing Record 42 of Set 13 | nexo
# Processing Record 43 of Set 13 | hervey bay
# Processing Record 44 of Set 13 | alugan
# Processing Record 45 of Set 13 | naryan-mar
# Processing Record 46 of Set 13 | suileng
# Processing Record 47 of Set 13 | lavrentiya
# Processing Record 48 of Set 13 | san borja
# Processing Record 49 of Set 13 | ahuimanu
# Processing Record 50 of Set 13 | baghdad
# Processing Record 1 of Set 14 | west des moines
# Processing Record 2 of Set 14 | tallahassee
# Processing Record 3 of Set 14 | livingstone
# Processing Record 4 of Set 14 | ahipara
# Processing Record 5 of Set 14 | araouane
# Processing Record 6 of Set 14 | tashtyp
# Processing Record 7 of Set 14 | smithers
# Processing Record 8 of Set 14 | aksarka
# Processing Record 9 of Set 14 | novyy urengoy
# Processing Record 10 of Set 14 | porto novo
# Processing Record 11 of Set 14 | mutoko
# Processing Record 12 of Set 14 | chilliwack
# Processing Record 13 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 14 of Set 14 | synya
# Processing Record 15 of Set 14 | yialos
# City not found. Skipping...
# Processing Record 16 of Set 14 | tonantins
# Processing Record 17 of Set 14 | sokna
# Processing Record 18 of Set 14 | torit
# Processing Record 19 of Set 14 | carbonia
# Processing Record 20 of Set 14 | rawson
# Processing Record 21 of Set 14 | husum
# Processing Record 22 of Set 14 | manbij
# Processing Record 23 of Set 14 | santa maria
# Processing Record 24 of Set 14 | san joaquin
# Processing Record 25 of Set 14 | eenhana
# Processing Record 26 of Set 14 | amuntai
# Processing Record 27 of Set 14 | yomou
# Processing Record 28 of Set 14 | ilebo
# Processing Record 29 of Set 14 | diapaga
# Processing Record 30 of Set 14 | ust-tsilma
# Processing Record 31 of Set 14 | ambilobe
# Processing Record 32 of Set 14 | halifax
# Processing Record 33 of Set 14 | saint-joseph
# Processing Record 34 of Set 14 | nuevo progreso
# Processing Record 35 of Set 14 | morro bay
# Processing Record 36 of Set 14 | lardos
# Processing Record 37 of Set 14 | paramonga
# Processing Record 38 of Set 14 | kodinsk
# Processing Record 39 of Set 14 | hanstholm
# Processing Record 40 of Set 14 | paamiut
# Processing Record 41 of Set 14 | rio gallegos
# Processing Record 42 of Set 14 | mosquera
# Processing Record 43 of Set 14 | chama
# Processing Record 44 of Set 14 | zhuji
# Processing Record 45 of Set 14 | atar
# Processing Record 46 of Set 14 | gazanjyk
# Processing Record 47 of Set 14 | coos bay
# Processing Record 48 of Set 14 | marsa matruh
# Processing Record 49 of Set 14 | lubu
# Processing Record 50 of Set 14 | selizharovo
# Processing Record 1 of Set 15 | puerto leguizamo
# Processing Record 2 of Set 15 | turayf
# Processing Record 3 of Set 15 | palu
# Processing Record 4 of Set 15 | moengo
# Processing Record 5 of Set 15 | haifa
# Processing Record 6 of Set 15 | beaufort
# Processing Record 7 of Set 15 | xique-xique
# Processing Record 8 of Set 15 | chato
# Processing Record 9 of Set 15 | meridian
# Processing Record 10 of Set 15 | lokosovo
# Processing Record 11 of Set 15 | hovd
# Processing Record 12 of Set 15 | kavaratti
# Processing Record 13 of Set 15 | puerto escondido
# Processing Record 14 of Set 15 | ternate
# Processing Record 15 of Set 15 | lazaro cardenas
# Processing Record 16 of Set 15 | kamaishi
# Processing Record 17 of Set 15 | maues
# Processing Record 18 of Set 15 | port lincoln
# Processing Record 19 of Set 15 | geilo
# Processing Record 20 of Set 15 | kapuskasing
# Processing Record 21 of Set 15 | pisco
# Processing Record 22 of Set 15 | najran
# Processing Record 23 of Set 15 | marovoay
# Processing Record 24 of Set 15 | portland
# Processing Record 25 of Set 15 | portobelo
# Processing Record 26 of Set 15 | jibuti
# Processing Record 27 of Set 15 | novopokrovka
# Processing Record 28 of Set 15 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 29 of Set 15 | embu
# Processing Record 30 of Set 15 | cedar city
# Processing Record 31 of Set 15 | wuan
# Processing Record 32 of Set 15 | ordynskoye
# Processing Record 33 of Set 15 | acapulco
# Processing Record 34 of Set 15 | opuwo
# Processing Record 35 of Set 15 | paracuru
# Processing Record 36 of Set 15 | kirensk
# Processing Record 37 of Set 15 | arcata
# Processing Record 38 of Set 15 | ibra
# Processing Record 39 of Set 15 | kasangulu
# Processing Record 40 of Set 15 | puerto maldonado
# Processing Record 41 of Set 15 | raga
# Processing Record 42 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 15 | glowno
# Processing Record 44 of Set 15 | pitimbu
# Processing Record 45 of Set 15 | ngunguru
# Processing Record 46 of Set 15 | gamboula
# Processing Record 47 of Set 15 | bull savanna
# Processing Record 48 of Set 15 | basoko
# Processing Record 49 of Set 15 | houma
# Processing Record 50 of Set 15 | uzumlu
# City not found. Skipping...
# Processing Record 1 of Set 16 | mayumba
# Processing Record 2 of Set 16 | cap malheureux
# Processing Record 3 of Set 16 | marsaxlokk
# Processing Record 4 of Set 16 | uvalde
# Processing Record 5 of Set 16 | constantine
# Processing Record 6 of Set 16 | adana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 694

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
WeatherPy_Database_Cities_df = pd.DataFrame(city_data)

# %%
# Display sample data
WeatherPy_Database_Cities_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Ushuaia -54.8000  -68.3000     58.66        44          75
# 1          Cayenne   4.9333  -52.3333     84.24        70          40
# 2             Lamu  -2.2717   40.9020     80.82        85          98
# 3             Lebu -37.6167  -73.6500     59.54        59           0
# 4           Avarua -21.2078 -159.7750     78.85        89          75
# 5     Punta Arenas -53.1500  -70.9167     53.71        54          75
# 6  Arraial Do Cabo -22.9661  -42.0278     76.86        83          75
# 7              Hit  33.6416   42.8251     62.98        56           0
# 8          Camacha  33.0833  -16.3333     62.02        82          40
# 9         Linjiang  41.8069  126.9078      4.12        88           3
#
#    Wind Speed Country              Description
# 0       16.11      AR            broken clouds
# 1       13.80      GF         scattered clouds
# 2        8.70      KE          overcast clouds
# 3       17.13      CL                clear sky
# 4       11.50      CK            broken clouds
# 5       21.85      CL            broken clouds
# 6       21.85      BR            broken clouds
# 7        7.54      IQ                clear sky
# 8       19.57      PT  light intensity drizzle
# 9        2.73      CN                clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
WeatherPy_Database_Cities_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

new_column_order = WeatherPy_Database_Cities_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]]

# Recreate the DataFrame by using the new column order
WeatherPy_Database_Cities_df = new_column_order

# Display sample data
WeatherPy_Database_Cities_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Ushuaia      AR -54.8000  -68.3000     58.66        44
# 1           Cayenne      GF   4.9333  -52.3333     84.24        70
# 2              Lamu      KE  -2.2717   40.9020     80.82        85
# 3              Lebu      CL -37.6167  -73.6500     59.54        59
# 4            Avarua      CK -21.2078 -159.7750     78.85        89
# ..              ...     ...      ...       ...       ...       ...
# 689  Cap Malheureux      MU -19.9842   57.6142     74.46        71
# 690      Marsaxlokk      MT  35.8419   14.5431     59.07        87
# 691          Uvalde      US  29.3669  -99.7670     50.32        52
# 692     Constantine      DZ  36.3650    6.6147     49.41        76
# 693           Adana      TR  36.9850   35.2881     62.62        77
#
#      Cloudiness  Wind Speed       Description
# 0            75       16.11     broken clouds
# 1            40       13.80  scattered clouds
# 2            98        8.70   overcast clouds
# 3             0       17.13         clear sky
# 4            75       11.50     broken clouds
# ..          ...         ...               ...
# 689           1        1.99         clear sky
# 690           0        4.61         clear sky
# 691         100        4.61   overcast clouds
# 692           0        2.30         clear sky
# 693          40        3.44  scattered clouds
#
# [694 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
WeatherPy_Database_Cities_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
WeatherPy_Database_Cities_df.to_csv(output_data_file, index_label="City_ID")
